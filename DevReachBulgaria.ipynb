# %% [markdown]
# # DevReach Bulgaria 2017
#
# -----------------------
#
# ![](http://investsofia.com/wp-content/uploads/2017/08/firefox_2017-08-13_20-19-19.png)
#
# ## Cognitive Services
# #### _Real-Life Use Cases for Artificial Intelligence_
#
# [Microsoft Cognitive Services](https://azure.microsoft.com/en-us/services/cognitive-services/) uses powerful algorithms to allow your applications to see, hear, speak, understand and interpret with just a few lines of code. Easily add intelligent features – such as emotion and sentiment detection, vision and speech recognition, language understanding, knowledge and search – into your app, across devices and platforms such as iOS, Android, and Windows. These services are constantly growing and improving based on utilization - so stay tuned for more examples!
#
# -------------
#
# # Vision
#
# #### Emotion API
# The Kevin Bacon age detection example, which leverages the Face API as well as the Emotion API,  can be found [here](https://github.com/dynamicwebpaige/azure-workshop/blob/master/well-aged-bacon.ipynb).
#
# #### Computer Vision API
# The coral reef image detection example can be found [here](https://github.com/dynamicwebpaige/azure-workshop/blob/master/coral_TNC.ipynb). Below is an example of detecting raw text from an image, also using the Computer Vision API. A full list of supported languages can be found [here](https://msdn.microsoft.com/en-us/library/hh456380.aspx), from Slovak to Klingon!
#
# ------------
#
# ## Detecting Cyrillic Text in an Image
# Hey! I recognize that guy!
#
# ![](http://4.bp.blogspot.com/-azhSS2fK6Ts/VhQaNJvmFrI/AAAAAAAAA4U/EAFtonT7sY8/s1600/SDC10865.JPG)

# %%
subscription_secret = 'INSERT YOUR KEY HERE'

import http.client, urllib.request, urllib.parse, urllib.error, base64, json

# Replace with your subscription key.
subscription_key = subscription_secret

# Declare region.
uri_base = 'westcentralus.api.cognitive.microsoft.com'

headers = {
    # Request headers.
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': subscription_key,
}

params = urllib.parse.urlencode({
    # Request parameters. 
    'language': 'unk',
    'detectOrientation ': 'true',
})

# The URL of a JPEG image containing text.
body = "{'url':'http://4.bp.blogspot.com/-azhSS2fK6Ts/VhQaNJvmFrI/AAAAAAAAA4U/EAFtonT7sY8/s1600/SDC10865.JPG'}"

try:
    # Execute the REST API call and get the response.
    conn = http.client.HTTPSConnection('westcentralus.api.cognitive.microsoft.com')
    conn.request("POST", "/vision/v1.0/ocr?%s" % params, body, headers)
    response = conn.getresponse()
    data = response.read()

    # 'data' contains the JSON data. The following formats the JSON data for display.
    parsed = json.loads(data.decode())
    print ("Response:")
    print (json.dumps(parsed, sort_keys=True, indent=2))
    conn.close()

except Exception as e:
    print('Error:')
    print(e)
# Out:
# Response:
# {
#   "language": "ru",
#   "orientation": "Up",
#   "regions": [
#     {
#       "boundingBox": "309,404,517,544",
#       "lines": [
#         {
#           "boundingBox": "312,404,269,42",
#           "words": [
#             {
#               "boundingBox": "312,404,269,42",
#               "text": "\u0420\u0415\u0421\u0422\u041e\u0420\u0410\u041d"
#             }
#           ]
#         },
#         {
#           "boundingBox": "309,455,517,54",
#           "words": [
#             {
#               "boundingBox": "309,455,249,54",
#               "text": "\u0412\u041a\u0423\u0421\u041d\u041e\u0419"
#             },
#             {
#               "boundingBox": "573,463,253,43",
#               "text": "\u041a\u0423\u0420\u041e\u0427\u041a\u0418"
#             }
#           ]
#         },
#         {
#           "boundingBox": "358,932,132,16",
#           "words": [
#             {
#               "boundingBox": "358,932,41,16",
#               "text": "(017)"
# ...

# %% [markdown]
# ## Translating Cyrillic Characters to Other Languages

# %%
import requests

# Get the key from tab Keys on Azure portal
key = "INSERT YOUR KEY HERE" 

url4authentication = 'https://api.cognitive.microsoft.com/sts/v1.0/issueToken'
headers4authentication = {'Ocp-Apim-Subscription-Key': key}
resp4authentication = requests.post(url4authentication, headers=headers4authentication)
token = resp4authentication.text

# Call the Text Translate API
text = """

бяло вино,

вкусна пържола, 

пиле Алфредо

"""
come = "bg"
to = "en"

url4translate = 'https://api.microsofttranslator.com/v2/http.svc/Translate'
params = {'appid': 'Bearer '+token, 'text': text, 'from': come, 'to': to}
headers4translate = {'Accept': 'application/xml'}
resp4translate = requests.get(url4translate, params=params, headers=headers4translate)
print(resp4translate.text)
# Out:
# <string xmlns="http://schemas.microsoft.com/2003/10/Serialization/">
#
# white wine, a tasty steak, chicken Alfredo
#
# </string>
